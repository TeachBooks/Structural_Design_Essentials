# %% [markdown]
# # Section tables
#
# ## Sawn sections
#
# ```{figure} Images/coordinate_system.png
# ---
# ---
# Coordinate system (bending around strong axis is around y-axis)
# ```
#
# ```{note}
# Remember that $I_y$, $I_z$, $W_y$ and $W_z$ are another notation for $I_{zz}$, $I_{yy}$, $W_{zz}$ and $W_{yy}$ respectively.
# ```
#
# ### Width 33 mm
# ```{table} Section tables for timber beams with width 33 mm.
# :name: sawn-timber-33-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ | $W_z \cdot 10^3 \ [mm^3]$ | $I_z \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|-----------|------------|
# | 69   | 22.77      | 26.19      | 90.34       | 12.52      | 20.66       |
# | 95   | 31.35      | 49.64      | 235.8       | 17.24      | 28.45       |
# | 120  | 39.60      | 79.20      | 475.2       | 21.78      | 35.94       |
# | 133  | 43.89      | 97.29      | 647.0       | 24.14      | 39.83       |
# | 145  | 47.85      | 115.6      | 838.4       | 26.32      | 43.42       |
# | 170  | 56.10      | 158.9      | 1 351       | 30.86      | 50.91       |
# | 195  | 64.35      | 209.1      | 2 039       | 35.39      | 58.40       |
# | 220  | 72.60      | 266.2      | 2 928       | 39.93      | 65.88       |
# | 245  | 80.85      | 330.1      | 4 044       | 44.47      | 73.37       |
# ```
#
# ### Width 45 mm
# ```{table} Section tables for timber beams with width 45 mm.
# :name: sawn-timber-45-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ | $W_z \cdot 10^3 \ [mm^3]$ | $I_z \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|-----------|------------|
# | 69   | 31.05      | 35.71      | 123.2       | 23.29      | 52.40       |
# | 95   | 42.75      | 67.69      | 321.5       | 32.06      | 72.14       |
# | 120  | 54.00      | 108.0      | 648.0       | 40.50      | 91.12       |
# | 133  | 59.85      | 132.7      | 882.2       | 44.89      | 101.0       |
# | 145  | 65.25      | 157.7      | 1 143       | 48.94      | 110.1       |
# | 170  | 76.50      | 216.8      | 1 842       | 57.38      | 129.1       |
# | 195  | 87.75      | 285.2      | 2 781       | 65.81      | 148.1       |
# | 220  | 99.00      | 363.0      | 3 993       | 74.25      | 167.1       |
# ```
#
# ### Width 58 mm
# ```{table} Section tables for timber beams with width 58 mm.
# :name: sawn-timber-58-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ | $W_z \cdot 10^3 \ [mm^3]$ | $I_z \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|-----------|------------|
# | 95   | 55.10      | 87.24      | 414.4       | 53.26      | 154.5       |
# | 120  | 69.60      | 139.2      | 835.2       | 67.28      | 195.1       |
# | 133  | 77.14      | 171.0      | 1 137       | 74.57      | 216.2       |
# | 145  | 84.10      | 203.2      | 1 474       | 81.30      | 235.8       |
# | 170  | 98.60      | 279.4      | 2 375       | 95.31      | 276.4       |
# | 195  | 113.1      | 367.6      | 3 584       | 109.3      | 317.1       |
# | 220  | 127.6      | 467.9      | 5 147       | 123.3      | 357.7       |
# | 245  | 142.1      | 580.2      | 7 108       | 137.4      | 398.4       |
# ```
#
# ### Width 69 mm
# ```{table} Section tables for timber beams with width 69 mm.
# :name: sawn-timber-69-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ | $W_z \cdot 10^3 \ [mm^3]$ | $I_z \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|-----------|------------|
# | 95   | 65.55      | 103.8      | 493.0       | 75.38      | 260.1       |
# | 120  | 82.80      | 165.6      | 993.6       | 95.22      | 328.5       |
# | 133  | 91.77      | 203.4      | 1 353       | 105.5      | 364.1       |
# | 145  | 100.0      | 241.8      | 1 753       | 115.1      | 396.9       |
# | 170  | 117.3      | 332.4      | 2 825       | 134.9      | 465.4       |
# | 195  | 134.6      | 437.3      | 4 264       | 154.7      | 533.8       |
# | 220  | 151.8      | 556.6      | 6 123       | 174.6      | 602.3       |
# | 245  | 169.1      | 690.3      | 8 456       | 194.4      | 670.7       |
# | 270  | 186.3      | 838.4      | 11 318      | 214.2      | 739.1       |
# ```
#
# ### Width 95 mm
# ```{table} Section tables for timber beams with width 95 mm.
# :name: sawn-timber-95-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ | $W_z \cdot 10^3 \ [mm^3]$ | $I_z \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|-----------|------------|
# | 195  | 185.2      | 602.1      | 5 870       | 293.3      | 1 393       |
# | 220  | 209.0      | 766.3      | 8 430       | 330.9      | 1 572       |
# | 245  | 232.8      | 950.4      | 11 642      | 368.5      | 1 750       |
# | 270  | 256.5      | 1 154      | 15 582      | 406.1      | 1 929       |
# ```
#
# ### Width 120 mm
# ```{table} Section tables for timber beams with width 120 mm.
# :name: sawn-timber-120-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ | $W_z \cdot 10^3 \ [mm^3]$ | $I_z \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|-----------|------------|
# | 195  | 234.0      | 760.5      | 7 415       | 468.0      | 2 808       |
# | 220  | 264.0      | 968.0      | 10 648      | 528.0      | 3 168       |
# | 245  | 294.0      | 1 200      | 14 706      | 588.0      | 3 528       |
# | 270  | 324.0      | 1 458      | 19 683      | 648.0      | 3 888       |
# ```
#
# ## Glued laminated timber
#
# ```{figure} Images/coordinate_system.png
# ---
# ---
# Coordinate system (bending around strong axis is around y-axis)
# ```
#
# ```{note}
# Remember that $I_y$, $I_z$, $W_y$ and $W_z$ are another notation for $I_{zz}$, $I_{yy}$, $W_{zz}$ and $W_{yy}$ respectively.
# ```
#
# ### Width 55 mm
# ```{table} Section tables for glued laminated timber beams with width 55 mm.
# :name: glulam-55-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 110.0      | 366.7      | 3 667       |
# | 250  | 137.5      | 572.9      | 7 161       |
# | 300  | 165.0      | 825.0      | 12 375      |
# | 350  | 192.5      | 1 123      | 19 651      |
# | 400  | 220.0      | 1 467      | 29 333      |
# | 450  | 247.5      | 1 856      | 41 766      |
# | 500  | 275.0      | 2 292      | 57 292      |
# | 550  | 302.5      | 2 773      | 76 255      |
# ```
#
# ### Width 85 mm
# ```{table} Section tables for glued laminated timber beams with width 85 mm.
# :name: glulam-85-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 170.0      | 566.7      | 5 667       |
# | 250  | 212.5      | 885.4      | 11 068      |
# | 300  | 255.0      | 1 275      | 19 125      |
# | 350  | 297.5      | 1 735      | 30 370      |
# | 400  | 340.0      | 2 267      | 45 333      |
# | 450  | 382.5      | 2 869      | 64 547      |
# | 500  | 425.0      | 3 542      | 88 542      |
# | 550  | 467.5      | 4 285      | 117 849     |
# | 600  | 510.0      | 5 100      | 153 000     |
# | 650  | 552.5      | 5 985      | 194 526     |
# | 700  | 595.0      | 6 942      | 242 958     |
# | 750  | 637.5      | 7 969      | 298 828     |
# | 800  | 680.0      | 9 067      | 362 667     |
# | 850  | 722.5      | 10 235     | 435 005     |
# ```
#
# ### Width 110 mm
# ```{table} Section tables for glued laminated timber beams with width 110 mm.
# :name: glulam-110-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 220.0      | 733.3      | 7 333       |
# | 250  | 275.0      | 1 146      | 14 323      |
# | 300  | 330.0      | 1 650      | 24 750      |
# | 350  | 385.0      | 2 246      | 39 302      |
# | 400  | 440.0      | 2 933      | 58 667      |
# | 450  | 495.0      | 3 712      | 83 531      |
# | 500  | 550.0      | 4 583      | 114 583     |
# | 550  | 605.0      | 5 546      | 152 510     |
# | 600  | 660.0      | 6 600      | 198 000     |
# | 650  | 715.0      | 7 746      | 251 740     |
# | 700  | 770.0      | 8 983      | 314 417     |
# | 750  | 825.0      | 10 312     | 386 719     |
# | 800  | 880.0      | 11 733     | 469 333     |
# | 850  | 935.0      | 13 246     | 562 948     |
# ```
#
# ### Width 135 mm
# ```{table} Section tables for glued laminated timber beams with width 135 mm.
# :name: glulam-135-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 270.0      | 900.0      | 9 000       |
# | 250  | 337.5      | 1 406      | 17 578      |
# | 300  | 405.0      | 2 025      | 30 375      |
# | 350  | 472.5      | 2 756      | 48 234      |
# | 400  | 540.0      | 3 600      | 72 000      |
# | 450  | 607.5      | 4 556      | 102 516     |
# | 500  | 675.0      | 5 625      | 140 625     |
# | 550  | 742.5      | 6 806      | 187 172     |
# | 600  | 810.0      | 8 100      | 243 000     |
# | 650  | 877.5      | 9 506      | 308 953     |
# | 700  | 945.0      | 11 025     | 385 875     |
# | 750  | 1 012      | 12 656     | 474 609     |
# | 800  | 1 080      | 14 400     | 576 000     |
# | 850  | 1 148      | 16 256     | 690 891     |
# | 900  | 1 215      | 18 225     | 820 125     |
# | 950  | 1 282      | 20 306     | 964 547     |
# | 1000 | 1 350      | 22 500     | 1 125 000   |
# | 1050 | 1 418      | 24 806     | 1 302 328   |
# | 1100 | 1 485      | 27 225     | 1 497 375   |
# | 1150 | 1 552      | 29 756     | 1 710 984   |
# | 1200 | 1 620      | 32 400     | 1 944 000   |
# | 1250 | 1 688      | 35 156     | 2 197 266   |
# | 1300 | 1 755      | 38 025     | 2 471 625   |
# | 1350 | 1 822      | 41 006     | 2 767 922   |
# ```
#
# ### Width 160 mm
# ```{table} Section tables for glued laminated timber beams with width 160 mm.
# :name: glulam-160-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 320.0      | 1 067      | 10 667      |
# | 250  | 400.0      | 1 667      | 20 833      |
# | 300  | 480.0      | 2 400      | 36 000      |
# | 350  | 560.0      | 3 267      | 57 167      |
# | 400  | 640.0      | 4 267      | 85 333      |
# | 450  | 720.0      | 5 400      | 121 500     |
# | 500  | 800.0      | 6 667      | 166 667     |
# | 550  | 880.0      | 8 067      | 221 833     |
# | 600  | 960.0      | 9 600      | 288 000     |
# | 650  | 1 040      | 11 267     | 366 167     |
# | 700  | 1 120      | 13 067     | 457 333     |
# | 750  | 1 200      | 15 000     | 562 500     |
# | 800  | 1 280      | 17 067     | 682 667     |
# | 850  | 1 360      | 19 267     | 818 833     |
# | 900  | 1 440      | 21 600     | 972 000     |
# | 950  | 1 520      | 24 067     | 1 143 167   |
# | 1000 | 1 600      | 26 667     | 1 333 333   |
# | 1050 | 1 680      | 29 400     | 1 543 500   |
# | 1100 | 1 760      | 32 267     | 1 774 667   |
# | 1150 | 1 840      | 35 267     | 2 027 833   |
# | 1200 | 1 920      | 38 400     | 2 304 000   |
# | 1250 | 2 000      | 41 667     | 2 604 167   |
# | 1300 | 2 080      | 45 067     | 2 929 333   |
# | 1350 | 2 160      | 48 600     | 3 280 500   |
# | 1400 | 2 240      | 52 267     | 3 658 667   |
# | 1450 | 2 320      | 56 067     | 4 064 833   |
# | 1500 | 2 400      | 60 000     | 4 500 000   |
# | 1550 | 2 480      | 64 067     | 4 965 167   |
# | 1600 | 2 560      | 68 267     | 5 461 333   |
# ```
#
# ### Width 185 mm
# ```{table} Section tables for glued laminated timber beams with width 185 mm.
# :name: glulam-185-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 370.0      | 1 233      | 12 333      |
# | 250  | 462.5      | 1 927      | 24 089      |
# | 300  | 555.0      | 2 775      | 41 625      |
# | 350  | 647.5      | 3 777      | 66 099      |
# | 400  | 740.0      | 4 933      | 98 667      |
# | 450  | 832.5      | 6 244      | 140 484     |
# | 500  | 925.0      | 7 708      | 192 708     |
# | 550  | 1 018      | 9 327      | 256 495     |
# | 600  | 1 110      | 11 100     | 333 000     |
# | 650  | 1 202      | 13 027     | 423 380     |
# | 700  | 1 295      | 15 108     | 528 792     |
# | 750  | 1 388      | 17 344     | 650 391     |
# | 800  | 1 480      | 19 733     | 789 333     |
# | 850  | 1 572      | 22 277     | 946 776     |
# | 900  | 1 665      | 24 975     | 1 123 875   |
# | 950  | 1 758      | 27 827     | 1 321 786   |
# | 1000 | 1 850      | 30 833     | 1 541 667   |
# | 1050 | 1 942      | 33 994     | 1 784 672   |
# | 1100 | 2 035      | 37 308     | 2 051 958   |
# | 1150 | 2 128      | 40 777     | 2 344 682   |
# | 1200 | 2 220      | 44 400     | 2 664 000   |
# | 1250 | 2 312      | 48 177     | 3 011 068   |
# | 1300 | 2 405      | 52 108     | 3 387 042   |
# | 1350 | 2 498      | 56 194     | 3 793 078   |
# | 1400 | 2 590      | 60 433     | 4 230 333   |
# | 1450 | 2 682      | 64 827     | 4 699 964   |
# | 1500 | 2 775      | 69 375     | 5 203 125   |
# | 1550 | 2 868      | 74 077     | 5 740 974   |
# | 1600 | 2 960      | 78 933     | 6 314 667   |
# | 1650 | 3 052      | 83 944     | 6 925 359   |
# | 1700 | 3 145      | 89 108     | 7 574 208   |
# | 1750 | 3 238      | 94 427     | 8 262 370   |
# | 1800 | 3 330      | 99 900     | 8 991 000   |
# ```
#
# ### Width 205 mm
# ```{table} Section tables for glued laminated timber beams with width 205 mm.
# :name: glulam-205-width
# | $h \ [mm]$ | $A \cdot 10^2 \ [mm^2]$ | $W_y \cdot 10^3 \ [mm^3]$ | $I_y \cdot 10^4 \ [mm^4]$ |
# |-----|-----------|-----------|------------|
# | 200  | 410.0      | 1 367      | 13 667      |
# | 250  | 512.5      | 2 135      | 26 693      |
# | 300  | 615.0      | 3 075      | 46 125      |
# | 350  | 717.5      | 4 185      | 73 245      |
# | 400  | 820.0      | 5 467      | 109 333     |
# | 450  | 922.5      | 6 919      | 155 672     |
# | 500  | 1 025      | 8 542      | 213 542     |
# | 550  | 1 128      | 10 335     | 284 224     |
# | 600  | 1 230      | 12 300     | 369 000     |
# | 650  | 1 332      | 14 435     | 469 151     |
# | 700  | 1 435      | 16 742     | 585 958     |
# | 750  | 1 538      | 19 219     | 720 703     |
# | 800  | 1 640      | 21 867     | 874 667     |
# | 850  | 1 742      | 24 685     | 1 049 130   |
# | 900  | 1 845      | 27 675     | 1 245 375   |
# | 950  | 1 948      | 30 835     | 1 464 682   |
# | 1000 | 2 050      | 34 167     | 1 708 333   |
# | 1050 | 2 152      | 37 669     | 1 977 609   |
# | 1100 | 2 255      | 41 342     | 2 273 792   |
# | 1150 | 2 358      | 45 185     | 2 598 161   |
# | 1200 | 2 460      | 49 200     | 2 952 000   |
# | 1250 | 2 562      | 53 385     | 3 336 589   |
# | 1300 | 2 665      | 57 742     | 3 753 208   |
# | 1350 | 2 768      | 62 269     | 4 203 141   |
# | 1400 | 2 870      | 66 967     | 4 687 667   |
# | 1450 | 2 972      | 71 835     | 5 208 068   |
# | 1500 | 3 075      | 76 875     | 5 765 625   |
# | 1550 | 3 178      | 82 085     | 6 361 620   |
# | 1600 | 3 280      | 87 467     | 6 997 333   |
# | 1650 | 3 382      | 93 019     | 7 674 047   |
# | 1700 | 3 485      | 98 742     | 8 393 042   |
# | 1750 | 3 588      | 104 635    | 9 155 599   |
# | 1800 | 3 690      | 110 700    | 9 963 000   |
# ```
