# %% [markdown]
# # Beton & Staal constructies opdracht 2023-2024
#
# Deze pagina geeft een beeld van deel 1 van de opdracht van het vak Beton- en Staalconstructies (CTB2220-14) zoals deze is gepubliceerd aan studenten in het jaar 2023-2024 in het tweede kwartaal. Het doel is om als extra voorbeeld te dienen, waardoor de student meer inzicht krijgt in het gedeelte van het vak dat over veiligheid gaat. In de opdracht zijn verschillende parameters afhankelijk gemaakt van de laatste 3 cijfers van het studentennummer. In de betreffende parameters zijn deze aangeduid met **X, Y en Z (1234XYZ)**. Omdat deze opdracht als voorbeeld dient, is in deze uitwerking gekozen voor de parametrisatie **X = 0, Y = 0 en Z = 0**.
#
# ```{note}
# The calculations serve as examples for educational purposes and not as guidance for practice.
# ```
#
# ```{Note}
# To provide more coherence in the Quick Reference, the flowchart for structural design developed by Lisette Klompenhouwer, Bsc (2015) is provided in the margin to allow for oversight in where we are in the design process. The full flowchart can be found here: {doc}`../../design_workflow/general_design_info`.
# ```
#
# ````{margin}
# **Problem analysis**
# ```{figure} Images/design_process_1.jpg
# ```
# The problem is already clear, as in this case the structure has already been given. Note that the consequence class needs to be determined by the student in question a.
# ````
#
# ## Inleiding
#
# In een schilderachtig stadje aan de rand van Amsterdam staat het huis van meneer en mevrouw van Wijk. Een charmante eengezinswoning met een betonnen bouwlaag die al vele herinneringen heeft verzameld. Toen hun gezin uitbreidde, besloten ze dat het tijd was voor meer ruimte. De vraag die hen bezighield, was hoe ze een extra verdieping konden toevoegen zonder de bestaande constructie te veel te belasten.  Meneer van Wijk ging naar ons constructiebureau voor advies. Onze collega, Maria, had het briljante idee om een lichtgewicht staalconstructie te gebruiken. Ze geloofde dat dit de perfecte oplossing zou zijn om een extra verdieping toe te voegen zonder de bestaande betonnen constructie en de fundering drastisch te hoeven aanpassen. Haar ontwerp was innovatief en beloofde het gezin van Wijk de ruimte die ze nodig hadden, zonder hun huis volledig te verbouwen. Helaas raakte Maria betrokken bij een ander dringend project en moest ze dit ontwerp loslaten. Dat is wanneer jij, als haar collega, de uitdaging op je neemt om haar visie tot leven te brengen. Jij duikt dieper in Maria's ontwerp en begint met het uitwerken van de details.
#
# ```{figure} Images/figuur1_3dmodel_dimensies_benamingen.png
# ---
# name: figuur1
# ---
# 3D-model met dimensies en benamingen
# ```
#
# ````{margin}
# **Schematisation structural system**
# ```{figure} Images/design_process_2.jpg
# ```
# The schematisation of the structure is given on the left.
# ````
#
# Het was een complexe taak om ervoor te zorgen dat de nieuwe staalconstructie naadloos zou integreren met de bestaande betonnen constructie. Met zorgvuldige berekeningen en grondig onderzoek begon het nieuwe ontwerp vorm te krijgen. {numref}`figuur1` toont een 3D-model en  {numref}`figuur2` en {numref}`figuur3` laten de mechanische ontwerptekeningen van de constructie zien. Meer ontwerptekeningen zijn in {ref}`content:BijlageA:labels` terug te vinden. Zoals eerder vermeld, bestaat de begane grondvloer van de eengezinswoning uit beton, terwijl de extra structuur voor de eerste- en tweede verdieping van staal is gemaakt. De begane grondvloer heeft een hoogte van **4 meter**, de eerste verdieping heeft een hoogte van **3 meter** en de tweede verdieping heeft een hoogte van **2,8 meter**, zoals weergegeven in {numref}`figuur3`. De hartop-hart afstand tussen de kolommen in de lengterichting bedraagt **5 meter**, terwijl de overspanning in de dwarsrichting afhankelijk is van je studentennummer (X), zoals aangegeven in {numref}`overspanning_X`. In het geval van de uitwerking geldt dus **X = 0, dus de overspanning is 3,5 m**.
#
# ```{table} Parametrisatie overspanning
# :name: overspanning_X
#
# | Studentnummer X | Overspanning [m] |
# |---|---|
# | 0 en 1 | 3,5 |
# | 2 en 3 | 4,0 |
# | 4 en 5 | 4,5 |
# | 6 en 7 | 5 |
# | 8 en 9 | 5,5 |
# ```
#
# ```{figure} Images/figuur2_mechanica_schema_dwarsrichting.png
# ---
# name: figuur2
# ---
# Mechanica schema dwarsrichting
# ```
#
# ```{figure} Images/figuur3_mechanicaschema_lengterichting.png
# ---
# name: figuur3
# ---
# Mechanica schema lengterichting
# ```
#
# De betonnen liggers op assen A, B en C zijn doorlopende liggers. De stalen dak liggers op assen 1,2,3 en 4 zijn ook doorlopende liggers.  De gordingen hebben een overspanning van 5 meter (ze zijn scharnierend verbonden aan de doorlopende stalen dak ligger) en de onderlinge afstand tussen de gordingen is afhankelijk van jouw studienummer. De stalen en betonnen profielen die in de constructie zijn gebruikt, zijn ook gebaseerd op je studentennummer en kan je terugvinden bij vraag 2 en 3 respectievelijk. Aan de achterkant van de woning zijn 3 stalen **tapse liggers** ontworpen om het balkon te ondersteunen (zie {numref}`figuur1`). Deze uitkragende liggers hebben een lengte van 4 meter. Bij vraag 2 vind je de profielafmetingen van het begin en het einde van deze tapse liggers (Het begin- en eindprofielen van de tapse ligger zijn aangeduid in {numref}`figuur3`).
#
# **Kanaalplaatvloeren** worden zowel voor de begane grondvloer als voor de verdiepingsvloer gebruikt. Deze vloeren dragen de belasting af in één specifieke richting, zoals aangegeven in de tekening van {numref}`figuurA2` in {ref}`content:BijlageA:labels`. Het dak over de gehele oppervlakte van het gebouw is voorzien van stalen dakplaten (zie {numref}`figuurA3` in {ref}`content:BijlageA:labels`). Ook de dakplaten dragen de belasting af in één richting
#
# ## Vraag 1: Veiligheid en Belastingen
#
# De constructie wordt gedimensioneerd op basis van de fundamentele belastingcombinaties met permanente-, en veranderlijke belastingen.
#
# ### Permanente belastingen
# De permanente belasting kan zowel het eigengewicht van de hoofdconstructie als de vloer- en dak elementen zijn. Het eigengewicht van de stalen dakelementen en kanaalplaatvloer zijn te vinden in {numref}`vloer_dakplaat`.
#
# ````{margin}
# **Selection of material**
# ```{figure} Images/design_process_3.jpg
# ```
# Material selection has already been completed by the creator of the assignment. On the left materials for the floors are chosen. Above also the concrete and steel elements have been selected.
# ````
#
# ```{table} Vloer- en dakplaten gegevens
# :name: vloer_dakplaat
# | Onderdeel | Symbool | Belasting $kN/m^2$ |
# |---|---|---|
# | Stalen dakplaat | $g_{k,eigengewicht,dakplaat}$ | 0.12 |
# | Kanaalplaatvloer | $g_{k,eigengewicht,kanaal}$ | 3.02 |
# ```
#
# ````{margin}
# **Estimation of structural dimensions, global sizing**
# ```{figure} Images/design_process_4.jpg
# ```
# Based on the student number X and the provided element sizes, the structural dimensions can be obtained.
# ````
#
# De afmeting van de stalen Gording, Stalen ligger, Stalen kolom, Betonnen ligger en betonnen kolom is in {numref}`profielen_afmetingen` te vinden:
#
# ```{table} Profielen afmetingen
# :name: profielen_afmetingen
# | X        | Overspanning dak [m] | Overspanning vloer [m] | Gording | Beton ligger [m²] | Beton kolom [m]  |
# |----------|----------------------|------------------------|---------|-------------------|------------------|
# | 0 en 1   | 1.75                 | 3.5                    | IPE140  | 0.2 x 0.35        | 0.15 x 0.15      |
# | 2 en 3   | 2                    | 4                      | IPE160  | 0.22 x 0.35       | 0.175 x 0.175    |
# | 4 en 5   | 2.25                 | 4.5                    | IPE180  | 0.24 x 0.37       | 0.2 x 0.2        |
# | 6 en 7   | 2.5                  | 5                      | IPE180  | 0.24 x 0.38       | 0.225 x 0.225    |
# | 8 en 9   | 2.75                 | 5.5                    | IPE180  | 0.25 x 0.4        | 0.25 x 0.25      |
# ```
#
# Naast het eigengewicht van de constructieve onderdelen is er ook een permanente belasting toegepast van $\mathbf{g_{k,permanent,dak} = 0.45 kN/m^2}$ op het stalen dak. Deze belasting is de permanente belasting die komt uit het plafond, isolatie materiaal, dakbedekking, en zonnepanelen. Ter illustratie dient {numref}`figuur4`.
#
# ```{figure} Images/figuur4_stalen_dak_principe.png
# ---
# name: figuur4
# ---
# Stalen dak principe
# ```
#
# Binnen wordt er een permanente vloerbelasting toegepast van $\mathbf{g_{k,permanent,vloer} = 0.25 kN/m^2}$. Deze belasting is de permanente belasting uit het plafond, afwerking van de vloer en kabels en leidingen. Ter illustratie dient {numref}`figuur5`.
#
# ```{figure} Images/figuur5_kanaalplaatvloer.png
# ---
# name: figuur5
# ---
# Kanaalplaatvloer
# ```
#
# De belasting ten gevolge van het eigengewicht van de gevelelementen worden voor deze opdracht gezien als verwaarloosbaar.
#
# ### Veranderlijke belastingen
#
# Voor de veranderlijke belastingen (belastingen die kunnen 'veranderen' gedurende de levensduur van de constructie) op het dak, wordt onderscheid gemaakt in opgelegde dakbelasting (onderhoud aan het dak), sneeuwbelasting en windbelasting. In het geval van de binnenruimtes wordt er rekening gehouden met de een belasting voor “verplaatsbare” wanden en normale binnen belasting. Deze belasting is ook te vinden in het $\textcolor{red}{\text{veiligheid dictaat in paragraaf 2.4.1}}$.
#
# #### Opgelegde dakbelasting
# Een k opgelegde dak belasting van $\mathbf{g_{k,opgelegd,dak} = 1.0 kN/m^2}$ grijpt aan over een aaneengesloten rechthoekige oppervlakte van maximaal $\mathbf{10 \ m^2}$. Dit oppervlak kan zich op een willekeurige plaats van het dakvlak bevinden, zie {numref}`figuur6`.
#
# ```{figure} Images/figuur6_dakbelasting.png
# ---
# name: figuur6
# ---
# Dakbelasting
# ```
#
# #### Sneeuwbelasting
# Met de sneeuwbelasting wordt er gerekend met $\mathbf{g_{k,sneeuw} = 0.56 kN/m^2}$. In verband met het hoogteverschil op as 3 zou er normaal gesproken ook gerekend moeten worden met een extra belasting voor ophoping van sneeuw. Dit is voor deze opdracht buiten beschouwing gelaten.
#
# #### Windbelasting
# In deze opdracht wordt de windbelasting (behalve de opwaartse wind van de uitkragende ligger) buiten beschouwing gelaten. Normaal heeft de wind een belangrijke invloed op de dimensionering op elementen zoals dakbalken en stabiliteitselementen.  De karakteristieke windbelasting is weergegeven in {numref}`figuur7`. $\mathbf{g_{k,wind,opwaards,balkon} = 0.82 kN/m^2}$.
#
# ```{figure} Images/figuur7_windbelasting.png
# ---
# name: figuur7
# ---
# Windbelasting
# ```
#
# #### Binnenruimtes + verplaatsbare wanden en balkon belasting
# Veranderlijke belasting in een binnenruimte staat voor belasting door personen, meubilair, etc. Er wordt een onderscheid gemaakt tussen de belasting binnen en op het terras.
#
# De karakteristiek waarde van de belasting op vloeren is gelijk aan $g_{k} = 1.75 kN/m^2$. Echter omdat de ruimte groot is en de eigenaren van het huis de mogelijkheid willen om de ruimtes zelf te kunnen indelen en later verbouwen is er gekozen om niet dragende wanden toe te passen. Deze wanden kunnen op iedere locatie van de vloer aanwezig zijn. Dit heten verplaatsbare scheidingswanden. Er wordt gerekend met de lichtste scheidingswand, deze mag in rekening worden gebracht als een gelijkmatig verdeelde belasting van 0.5kN/m2. Dit brengt de totale (binnen)vloer belasting op  $\mathbf{g_{k,opgelegd,vloer} = 2.25 kN/m^2}$.
#
# De belasting op het balkon is volgens de Eurocode gelijk aan $\mathbf{g_{k,opgelegd,balkon} = 2.5 kN/m^2}$.
#
# ```{Note}
# In alle berekeningen wordt gebruikgemaakt van $\mathbf{g = 10.0 \ m/s^2}$!
# ```
#
# ### Classificatie
#
# :::{card}
# $\mathbf{\text{Vraag a}}$
# Voorafgaande aan het opstellen van de belastingcombinaties dient de gevolgklasse te zijn bepaald. Dit hangt af van de gebruiksfunctie van de constructie. In welke gevolgklasse moet deze constructie worden ingedeeld?
#
# `````{admonition} Uitwerking
# :class: tip, dropdown
# CC1
# `````
#
# $\mathbf{\text{Vraag b}}$
# Is er een verandering in gevolgklasse als de eigenaar ervoor gekozen had om 4 bouwlagen toe te passen? (tip: kijk in de NEN-EN 1990:2019/NB:2019 nl, dit is niet te vinden in de reader)
#
# `````{admonition} Uitwerking
# :class: tip, dropdown
# CC2
# `````
#
# $\mathbf{\text{Vraag c}}$
# Welke belasting factoren moeten er gehanteerd worden voor (on)gunstig werkende permanente en veranderlijke belastingen?
# - Permanent gunstig
# - Permanent ongunstig
# - Variabel gunstig
# - Variabel ongunstig
# - BGT permanent
# - BGT variablel
#
# Hierbij kan gebruik worden gemaakt van {doc}`../../design_workflow/general_loads/loads_limit_states`.
#
# `````{admonition} Uitwerking
# :class: tip, dropdown
# - Permanent gunstig: 0.9
# - Permanent ongunstig: 1.1 of 1.2
# - Variabel gunstig: 0
# - Variabel ongunstig: 1.35
# - BGT permanent: 1
# - BGT variablel: 1
# `````
# :::
#
# ````{margin}
# **Load determination**
# ```{figure} Images/design_process_5.jpg
# ```
# Here the loads should be determined.
# ````
#
# ### Belastingen
#
# :::{card}
# $\mathbf{\text{Vraag d}}$
# Bepaal de onderstaande karakteristieke permanente belastingen in [kN/m] die werkzaam zijn op de constructiedelen. Voor staalprofielen kan je gebruik maken van de app Staalprofielen van Bouwen met Staal of de website: https://www.bouwenmetstaal.nl/tools/staalprofielen. Kijk verder voor de h.o.h. overspanningen van de daken goed naar {ref}`content:BijlageA:labels`.
# - $G_{gording,as,B}$
# - $G_{uitkraging,as,B}$, ookwel tapse ligger, gebruik voor deze vraag het beginprofiel
# - $G_{stalenkolom,as,B2}$
# - $G_{dakligger,as,2}$
# - $G_{betonligger,as,B}$
# - $G_{betonkolom,as,B2}$
# - $G_{dak,as,B}$
# - $G_{vloer,as,B}$
#
# ```{table} Profielafmetingen vraag d
# :name: profiel_d
# | Studentnummer X | Tapse ligger beginprofiel | Stalen ligger | Stalen kolom |
# |---------------|--------------|---|---|
# | 0 of 1 | IPE400 | IPE120 | HEA120 |
# | 2 of 3 | IPE450 | IPE140 | HEA140 |
# | 4 of 5 | IPE450 | IPE160 | HEA160 |
# | 6 of 7 | IPE500 | IPE180 | HEA180 |
# | 8 of 9 | IPE500 | IPE200 | HEA200 |
# ```
#
# `````{admonition} Uitwerking
# :class: tip, dropdown
# - Uit {numref}`profielen_afmetingen` volgt dat de gording voor **X=0** bestaat uit IPE140, dit staalprofiel geeft $G = 12.9 \ kg/m$. Hieruit volgt: $G_{gording,as,B} = \frac{G}{100} = \frac{12.9}{100} = 0.129 \ kN/m$
# - Uit {numref}`profiel_d` volgt dat de tapse uitkraging voor **X=0** bestaat uit IPE400, dit staalprofiel geeft $G = 66.3 \ kg/m$. Hieruit volgt: $G_{uitkraging,as,B} = \frac{G}{100} = \frac{66.3}{100} = 0.663 \ kN/m$
# - Uit {numref}`profiel_d` volgt dat de stalen kolom voor **X=0** bestaat uit IPE120, dit staalprofiel geeft $G = 10.4 \ kg/m$. Hieruit volgt: $G_{stalenkolom,as,B2} = \frac{G}{100} = \frac{10.4}{100} = 0.104 \ kN/m$
# - Uit {numref}`profiel_d` volgt dat de gording voor **X=0** bestaat uit HEA120, dit staalprofiel geeft $G = 19.9 \ kg/m$. Hieruit volgt: $G_{dakligger,as,2} = \frac{G}{100} = \frac{19.9}{100} = 0.199 \ kN/m$
# - Uit {numref}`profielen_afmetingen` volgt dat de betonnen ligger voor **X=0** de afmeting heeft van $0.2 \ m \ x \ 0.35 \ m$, de dichtheid van gewapen beton is $25 \ kN/m^3$. Hieruit volgt: $G_{betonligger,as,B} = b * h * \rho_{beton} = 0.2 * 0.35 * 25 = 1.75 \ kN/m$
# - Uit {numref}`profielen_afmetingen` volgt dat de betonnen kolom voor **X=0** de afmeting heeft van $0.15 \ m \ x \ 0.15 \ m$, de dichtheid van gewapen beton is $25 \ kN/m^3$. Hieruit volgt: $G_{betonkolom,as,B2} = b * h * \rho_{beton} = 0.15 * 0.15 * 25 = 0.5625 \ kN/m$
# - Uit {numref}`profielen_afmetingen` volgt voor **X=0** de overspanning van het dak. $G_{dak,as,B} = (G_{dakplaten} + G_{perm,dakbelasting})*h.o.h._{overspanning,dak}$
# $= (0.12 + 0.45) * 1.75 = 0.9975 \ kN/m$
# - Uit {numref}`profielen_afmetingen` volgt voor **X=0** de overspanning van de vloer. $G_{vloer,as,B} = (G_{kanaalplaatvloer} + G_{perm,vloerbelasting})*h.o.h._{overspanning,vloer}$
# $= (3.02 + 0.25) * 3.5 = 11.655 \ kN/m$
# `````
#
# $\mathbf{\text{Vraag e}}$
# Bepaal de onderstaande karakteristieke veranderlijke belastingen in [kN/m] die werkzaam zijn op de constructiedelen.
# - $Q_{sneeuw,gording,as,B}$
# - $Q_{dakbelasting,gording,as,B}$
# - $Q_{terras,uitkraging,as,b}$
# - $Q_{opwaartse,wind,as,B}$
# - $Q_{binnen,as,B}$
#
# `````{admonition} Uitwerking
# :class: tip, dropdown
# Alle waardes volgen uit de bovenstaande tekst, net als de overspanningen in {numref}`profielen_afmetingen`, gevisualiseerd in {ref}`content:BijlageA:labels`.
# - $Q_{sneeuw,gording,as,B} = q_{sneeuw}*h.o.h._{overspanning,dak} = 0.56 * 1.75 = 0.98 \ kN/m$
# - $Q_{dakbelasting,gording,as,B} = q_{dak}*h.o.h._{overspanning,dak} = 1 * 1.75 = 1.75 \ kN/m$
# - $Q_{terras,uitkraging,as,b} = q_{terras}*h.o.h._{overspanning,vloer} = 2.5 * 3.5 = 8.75 \ kN/m$
# - $Q_{opwaartse,wind,as,B} = q_{wind}*h.o.h._{overspanning,vloer} = 0.82 * 3.5 = 2.856 \ kN/m$
# - $Q_{binnen,as,B} = q_{binnen}*h.o.h._{overspanning,vloer} = 2.25 * 3.5 = 7.875 \ kN/m$
# `````
# :::
#
# ### Combinaties
#
# :::{card}
# $\mathbf{\text{Vraag f}}$
# Voor het maatgevende negatieve moment in de uitkragende ligger op as B is de volgende belasting combinatie opgesteld: $\textit{ongunstig werkend eigengewicht}$, $\textit{opwaartse wind}$, $\textit{sneeuw belasting}$ en $\textit{terras belasting met ψ-factor}$. Dit is echter niet de juiste combinatie. Leg uit waarom dit niet juist is en geef de juiste combinatie (hier is geen berekening voor nodig).
#
# `````{admonition} Uitwerking
# :class: tip, dropdown
# Het maatgevende $\textbf{negatieve moment}$ in de uitkraging is als alle $\textbf{belastingen naar beneden}$ gericht zijn.
# - Wind van onder (opwaarts), geeft dus een kleiner negatief moment, dus onjuist
# - Sneeuwbelasting ($0.56 \ kN/m^2$) heeft $\psi_0 = 0$, terrasbelasting ($2.5 \ kN/m^2$) heeft $\psi_0 = 0.4$, deze kunnen niet tegelijkertijd aanwezig zijn zonder $\psi$-factor. De sneeuwbelasting is het kleinste dus deze valt weg.
#
# De goede combinatie volgens CC1 is dan: $\mathbf{1.1*q_eigengewicht + 1.35*q_{terras}}$
# `````
#
# $\mathbf{\text{Vraag g}}$
# Geef voor de stalen gording op as B de maximale oplegreacties:
#
# (i) Doe dit voor de Permanente belasting, Sneeuw belasting en de opgelgede Dakbelasting
# `````{admonition} Uitwerking
# :class: tip, dropdown
# De stalen gording kan worden geschematiseerd als een ligger op 2 steunpunten. Naar beide steunpunten gaat de helft van de belasting. Dit maakt de bereningen eenvoudig:
# - $R_{max,perm} = 0.5 * q_{perm} * L =$
# $= 0.5 * (G_{gording,as,B} + g_{dakplaat}*h.o.h._{overspanning,dak} + g_{k,perm,dak}*h.o.h._{overspanning,dak}) * L$
# $= 0.5 * (0.129 + 0.12*1.75 + 0.45*1.75) * 5 = 2.81625 \ kN$
# - $R_{max,sneeuw} = 0.5 * Q_{sneeuw} * L = 0.5 * 0.98 * 5 = 2.45 \ kN$
# - $R_{max,dak,opgelegd} = 0.5 * Q_{dakbelasting,gording,as,B} * L = 0.5 * 1.75 * 5 = 4.375 \ kN$
# `````
#
# (ii) Wat is de $\textbf{maatgevende veranderlijke belasting}$?
# `````{admonition} Uitwerking
# :class: tip, dropdown
# De maatgevende veranderlijke belasting is $\mathbf{R_{max,dak,opgelegd}}$
# `````
#
# $\mathbf{\text{Vraag h}}$
# Geef voor de betonnen ligger op as B de maatgevende belasting combinatie voor het maximale veld- en steunpunt moment (inclusief belastingfactoren, het gaat dus om de ontwerp waarde). Maak hierbij gebruik van {doc}`../../design_workflow/general_mechanics/beams_with_multiple_supports`
#
# ````{margin}
# **Load determination per structural element**
# ```{figure} Images/design_process_6.jpg
# ```
# All relevant loads are collected here for the concrete beam.
# ````
#
# (i) Teken de 5 verschillende belasting combinaties die horen bij de maatgevende ultimate limit state volgens {doc}`../../design_workflow/general_loads/loads_limit_states` in de constructie schema’s. Het constructieschema bestaat uit een doorgaande ligger op 4 steunpunten.
# `````{admonition} Uitwerking
# :class: tip, dropdown
# Uit {doc}`../../design_workflow/general_loads/loads_limit_states` in combinatie met de belastingen in deze opdracht volgt dat Design Situation 2 maatgevend is. Gezien het gaat om CC1, geldt $K_{Fl} = 0.9$. Daarmee wordt de maatgevende belastingcombinatie:
# $\mathbf{1.1*q_{per} + 1.35*q_{ver}}$
#
# Daarbij is het belangrijk om op te merken dat het eigen gewicht permanent is en dus vast en het veranderlijke gewicht niet, je kunt er dus bij die laatste voor kiezen om die wel of niet te plaatsen. Dit levert dus na uitsluiting door symmetrie de volgende 5 mogelijkheden op in {numref}`5combinaties`.
# ```{figure} Images/5_belastingcombinaties.png
# ---
# name: 5combinaties
# ---
# 5 verschillende belastingcombinaties
# ```
# De verschillende combinaties komen overeen met de situaties j (voor het eigen gewicht) + een keuze uit j t/m n in design_workflow/general_mechanics/beams_with_multiple_supports`. Controleer maar dat:
# - j = 2 (maar dus ook 1, gezien het eigengewicht gegarandeerd aanwezig is)
# - k = 6
# - l = 5
# - m = 4
# - n = 3
# `````
#
# (ii) Zoek met behulp van de tabellen van {doc}`../../design_workflow/general_mechanics/beams_with_multiple_supports`
#  de maatgevende belasting combinatie voor het veld moment en steunpunt moment.
# `````{admonition} Uitwerking
# :class: tip, dropdown
# Wanneer je uit {doc}`../../design_workflow/general_mechanics/beams_with_multiple_supports` de rijen en kolommen verwijdert die niet nodig zijn voor de momenten in deze opdracht levert dat {numref}`veld_steun_momenten` op. Voor de momenten moeten de waardes in {numref}`veld_steun_momenten` vermenigvuldigt worden met $q*L^2$. Voor **X = 0** geldt $L = 5 \ m$. De belastingfactoren $\mathbf{1.1}$ voor $\mathbf{q_{per}}$ en $\mathbf{1.35}$ voor $\mathbf{q_{ver}}$ worden in de uiteindelijke sommatie pas meegenomen en in eerste instantie weggelaten.
#
# ```{table} Veld- en steunpuntsmomenten factoren
# :name: veld_steun_momenten
# | Type | M(1) | M2     | M(2) | M3     | M(3) |
# |------|--------|--------|-----|--------|------|
# | j    | 0.0800 | -0.1000                    | 0.0250 | -0.100  | 0.0800 |
# | k    | 0.1013 | -0.0500                    | -0.0500| -0.0500 | 0.1013 |
# | l    | -0.025 | -0.0500                    | 0.0750 | -0.0500 | |
# | m    | 0.0735 | -0.1167                    | 0.0535 | -0.0333 | |
# | n    | 0.0939 | -0.0667                    | -0.0250| 0.0167  | |
# ```
#
# Voor de permanente belasting (type j), die bestaat uit het eigengewicht van de betonnnen ligger en de vloer geldt: $q = G_{betonligger,as,B} + G_{vloer,as,B} = 1.75 + 11.655 = 13.405 \ kN/m$. Combinatie van de eerdere factor uit {numref}`veld_steun_momenten`, $L = 5 \ m$ en q levert {numref}`momenten_permanent`.
#
# ```{table} Veld- en steunpuntsmomenten permanente belasting
# :name: momenten_permanent
# | Type | M(1) | M2     | M(2) | M3     | M(3) |
# |------|---------------------------|--------|----------------------------|--------|------|
# | j    | 26.81                   | -33.51 | 8.38                    | -33.51 | 26.81 |
# ```
#
# Voor de variable belasting (types j t/m n), die bestaat uit het eigengewicht van de betonnnen ligger en de vloer geldt: $q = Q_{binnen,as,B} = 7.875 \ kN/m$. Combinatie van de eerdere factor uit {numref}`veld_steun_momenten`, $L = 5 \ m$ en q levert {numref}`momenten_veranderlijk`.
#
# ```{table} Veld- en steunpuntsmomenten variabele belasting
# :name: momenten_veranderlijk
# | Type | M(1)   | M2      | M(2)    | M3      | M(3)    |
# |------|--------|---------|---------|---------|---------|
# | j    | 15.750 | -19.688 | 4.922   | -19.688 | 15.750  |
# | k    | 19.943 | -9.844  | -9.844  | -9.844  | 19.943  |
# | l    | -4.922 | -9.844  | 14.766  | -9.844  | 0.000   |
# | m    | 14.470 | -22.975 | 10.533  | -6.556  | 0.000   |
# | n    | 18.487 | -13.132 | -4.922  | 3.288   | 0.000   |
# ```
#
# Sommatie van de permanente belasting type j met de verscheide types voor de veranderlijke belasting levert de momenten in {numref}`sommatie`. In deze sommatie slaat het type belastingcombinatie terug op de veranderlijke belasting, gezien de permanente belasting altijd j is. De belastingfactoren $\mathbf{1.1}$ voor $\mathbf{q_{per}}$ en $\mathbf{1.35}$ voor $\mathbf{q_{ver}}$ worden nu meegenomen.
#
# ```{table} Veld- en steunpuntsmomenten
# :name: sommatie
# | Type | M(1)   | M2      | M(2)    | M3      | M(3)    |
# |------|--------|---------|---------|---------|---------|
# | j    | 50.754 | -63.442 | 15.860  | -63.442 | 50.754  |
# | k    | 56.415 | -50.153 | -4.073  | -50.153 | 56.415  |
# | l    | 22.846 | -50.153 | 29.150  | -50.153 | 29.491  |
# | m    | 49.026 | -67.880 | 23.435  | -45.714 | 29.491  |
# | n    | 54.448 | -54.591 | 2.571   | -32.425 | 29.491  |
# ```
# `````
#
# ````{margin}
# **M-lines**
# ```{figure} Images/design_process_7.jpg
# ```
# The moments on the concrete beam are determined.
# ````
#
# (iii) Bereken de maximale momenten.
# `````{admonition} Uitwerking
# :class: tip, dropdown
# Uit de {numref}`sommatie` volgen de maximale waardes:
# $\mathbf{Maximale \ veldmoment = 56.41 \ kNm}$ voor $\mathbf{combinatie \ k}$
# $\mathbf{Maximale \ steunpuntsmoment = -67.88 \ kNm}$ voor $\mathbf{combinatie \ m}$
# `````
#
# (iv) Teken de momentenlijn voor het maximale veld moment en de momentenlijn voor het maximale steunpunt moment.
# `````{admonition} Uitwerking
# :class: tip, dropdown
# De momenten zijn getekend in {numref}`schetsen_momentenlijnen`.
# ```{figure} Images/schetsen_momenten.jpg
# ---
# name: schetsen_momentenlijnen
# ---
# Schetsen momentenlijnen
# ```
# `````
#
# $\mathbf{\text{Vraag i}}$
# Geef voor de betonnen kolom op de kruising van as B en as 2 de maatgevende belasting combinatie voor de maximale drukkracht (rekenwaarde $R_d$, dus inclusief belastingfactoren). Gebruik {numref}`gegevens_i`. Daarnaast zijn de volgende lasten van belang:
# - $\textbf{EG Beton Kolom [kN/m]}$: Bepaald in opdracht d
# - $\textbf{Permanente Vloerbelasting [kN]}$: Gebruik Quick Reference om reactie kracht te bepaling van ligger opdracht h
# - $\textbf{Veranderlijke Vloerbelasting [kN]}$: Gebruik Quick Reference om reactie kracht te bepaling van ligger opdracht h
#
# ```{table} Gegevens vraag i
# :name: gegevens_i
# | X  | EG Stalen Kolom [kN/m] | Permanente Dakbelasting [kN] | Veranderlijke Dakbelasting [kN] |
# |--------|------|-------|-------|
# | 0 en 1 | 0.60 | 13.79 | 20.78 |
# | 2 en 3 | 0.74 | 16.01 | 23.75 |
# | 4 en 5 | 0.91 | 18.29 | 23.75 |
# | 6 en 7 | 1.07 | 20.08 | 23.75 |
# | 8 en 9 | 1.27 | 22.31 | 23.75 |
# ```
#
# In het geval van de uitwerking geldt **X = 0, dus EG Stalen Kolom = 0.60 [kN/m], Permanente Dakbelasting = 13.79 [kN] en Veranderlijke Dakbelasting = 20.78 [kN]**.
#
# (i) Teken belasting op de constructie schema's per individuele belasting
# `````{admonition} Uitwerking
# :class: tip, dropdown
# De 6 belastingen zijn getekend in {numref}`6_belastingen`.
# ```{figure} Images/6_belastingen.png
# ---
# name: 6_belastingen
# ---
# 6 belastingen
# ```
# `````
#
# (ii) Bereken de $\textbf{maatgevende ontwerp rekenwaarde van de drukkracht}(R_d)$
# `````{admonition} Uitwerking
# :class: tip, dropdown
# De drukkracht bestaat uit een sommatie van verschillende krachten icm belastingfactoren:
# - **Stalen kolom eigen gewicht**
# $R_{stalen,kolom} = h * q_{stalen,kolom} = 3 * 0.60 = 1.80 \ kN$
# - **Permanente dakbelasting**
# Gegeven: $R_{per,dak} = 13.79 \ kN$
# - **Veranderlijke dakbelasting**
# Gegeven: $R_{ver,dak} = 20.78 \ kN$
# - **Eigen gewicht beton kolom**
# $R_{beton,kolom} = h * q_{beton,kolom} = 4 * 0.5625 = 2.25 \ kN$
# - **Permanente vloerbelasting**
# Uit {doc}`../../design_workflow/general_mechanics/beams_with_multiple_supports` is de relevante informatie die van R2 (oplegreactie 2), gezien het om as B2 gaat (zie {numref}`figuur1`). Deze factoren die nodig zijn, zijn opgeslagen in {numref}`reactiekrachten`. Deze factor moet vermenigvuldigd worden met $q*L$.
# ```{table} Reactiekrachten beton ligger
# :name: reactiekrachten
# | Type | R2     |
# |------|--------|
# | j    | 1.1000 |
# | k    | 0.5500 |
# | l    | 0.5500 |
# | m    | 1.2001 |
# | n    | 0.6501 |
# ```
# Gezien het om een permanente belasting gaat is slechts type j relevant. Eerder was al vastgesteld $q = 13.405 \ kN/m$. Dus de reactiekracht van de permanente vloerbelasting is:
# $R_{per,vloer} = factor * q * L = 1.1 * 13.405 * 5 = 73.7275 \ kN$
# - **Veranderlijke vloerbelasting**
# Gezien het om een variable belasting gaat is slechts de grootste, type m, relevant. Eerder was al vastgesteld $q = 7.875 \ kN/m$. Dus de reactiekracht van de permanente vloerbelasting is:
# $R_{ver,vloer} = factor * q * L = 1.2001 * 7.875 * 5 = 47.254 \ kN$
#
# De belastingfactoren $\mathbf{1.1}$ voor $\mathbf{q_{per}}$ en $\mathbf{1.35}$ voor $\mathbf{q_{ver}}$ worden nu meegenomen. Dit levert de volgende reactiekracht op boven aan de kolom:
# $R_{tot,boven} = 1.1*q_{per} + 1.35*q_{ver}$
# $= 1.1*(R_{stalen,kolom} + R_{per,dak} + R_{per,vloer}) + 1.35*(R_{ver,vloer})$
# $= 1.1*(1.80 + 13.79 + 73.7275) + 1.35*(47.254) = 162.04 \ kN$
# ```{Note}
# De veranderelijke dakbelasting valt weg, gezien de veranderlijke vloerbelasting groter is en dus karakteristiek wordt genomen!
# ````
#
# Onder aan de kolom komt de belasting van het eigengewicht van de kolom erbij:
# $R_{tot,beneden} = R_{tot,boven} + 1.1*R_{beton,kolom}$
# $= 162.04 + 1.1*2.25 = 164.52 \ kN$
# `````
#
# (iii) Teken de N-lijn
# `````{admonition} Uitwerking
# :class: tip, dropdown
# Met behulp van de waardes uit deelvraag (ii) kan de N-lijn worden getekend in {numref}`n_lijn`.
# ```{figure} Images/n_lijn.jpg
# ---
# name: n_lijn
# ---
# N-lijn
# ```
# `````
# :::
#
# ````{margin}
# The following steps are not considered in the design. They are part of follow-up questions on this assignment.
# **Check ULS**
# ```{figure} Images/design_process_8.jpg
# ```
# **Check SLS**
# ```{figure} Images/design_process_9.jpg
# ```
# **Structural Design Ready**
# ```{figure} Images/design_process_10.jpg
# ```
# ````

# %% [markdown]
# (content:BijlageA:labels)=
# ## Bijlage A - Ontwerptekeningen
#
# ```{figure} Images/figuurA1_3dmodel_met_kanaalplaatvloeren_en_stalendakplaten.png
# ---
# name: figuurA1
# ---
# 3D model met kanaalplaatvoer en stalen dakplaten
# ```
#
# ```{figure} Images/figuurA2_plattegrond_eerste_verdieping.png
# ---
# name: figuurA2
# ---
# Plattegrond eerste verdieping
# ```
#
# ```{figure} Images/figuurA3_plattegrond_tweede_verdieping.png
# ---
# name: figuurA3
# ---
# Plattegrond tweede verdieping
# ```
#
# ```{figure} Images/figuurA4_plattegrond_dak.png
# ---
# name: figuurA4
# ---
# Plattegrond dak
# ```
