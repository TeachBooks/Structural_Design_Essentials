# %% [markdown]
# # The Structural Carbon Tool
#
# Calculating embodied carbon in the same rigorous way across all designs will allow meaningful comparisons to be made between structural schemes, developing our understanding of embodied carbon as well as how the industry can most effectively reach net zero carbon. This guidance is equally applicable to infrastructure and building projects. The calculation of embodied carbon must become a key part of every design process. Such efforts support the immediate need to reduce resource demand and increase reuse and recycling to enable a circular economy.
#
# This guidance will:
# - Help you select and specify materials that are efficient while ensuring they're safe and durable
# - Establish an agreed set of principals for the measuring of embodied carbon
# - Reduce the amount of carbon you use in your projects
# - Quantify the benefits of low carbon design to the client and society
# - Inform you about alternative ways you can move towards net zero carbon design
# - This guide has been translated into an open-source Excel estimator, [The Structural Carbon Tool Version 2](../LCA/TSCT_download.xlsm). The tool can be used to quickly identify ways in which to minimise embodied carbon on your designs.
#
# The following videos will explain how The Structural Carbon Tool works.
#
# ## Video 1: Introduction
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/6K71NT3iNBA?si=IzqPq30Ef8e-zcQH"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
#
# ## Video 2: Project info sheet
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/2NMb4_kiPlI?si=G1dRiKSPaRt5fb5x"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
#
# ## Video 3: Scheme input sheets
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/kQ4P7neUcPg?si=ac_UYodv_xBQcNZn"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
#
# ## Video 4: Comparison sheet
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/JKKXBrXfLCs?si=B6Gk7eL4HuJ0OT7N"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
#
# ## Video 5: Lifecycle material data
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/n4WGYyzKiTs?si=6sNmhkRts526P3nZ"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
#
# ## Video 6: Custom data
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/8NHSbaraFUI?si=oAARC-2H_3_e8fj5"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
#
# ## Video 7: Example uses
# <iframe
# width="560"
# height="315"
# src="https://www.youtube.com/embed/rflYy5aSQLE?si=YMtzwL-if5tr8Y3V"
# title="YouTube video player"
# frameborder="0"
# allowfullscreen
# ></iframe>
