# %% [markdown]
# # Permanent loads

# %% [markdown]
# Permanent loads on a structure consist of the dead weight of the considered
# component and the dead weight of the other components resting on the
# considered component. With the aid of the tables given below
# the one can determine the permanent loads for a given building. Note that for
# specific structural elements (I-beams or hollow core slabs) separate tables
# may exist with information on dead weight.

# %% [markdown]
# ## Materials (structural)
#
# ### Primary building materials
#
# ```{table} Density of primary building materials.
# :name: primary-building-materials-density
# | Material          | ρ [$kg/m^3$] |
# |--------------------------|------------------|
# | **Dunesand**             |                  |
# | - dry                    | 1550             |
# | - humid                  | 1700             |
# | - saturated              | 1950             |
# | **River- and Pebble-sand** |                  |
# | - dry                    | 1650             |
# | - humid                  | 1750             |
# | - saturated              | 2000             |
# | **Gravel**               |                  |
# | - dry                    | 1600             |
# | - humid                  | 1700-2000        |
# | - saturated              | 1922             |
# | **Soil and Clay**        |                  |
# | - dry                    | 1600             |
# | - wet                    | 2000             |
# | **Natural Stone**        |                  |
# | **Basalt, Granite**      | 2850             |
# | **Limestone, Marble**    | 2700             |
# | **Shale**                | 2700             |
# ```
#
# ### Secondary building materials
# ```{table} Density of secondary building materials.
# :name: secondery-building-materials-density
# | Material         | ρ [$kg/m^3$] |
# |-----------------------|------------------|
# | Ash                   | 1000             |
# | Blast Furnace Slag     | 1700             |
# ```
#
# ### Masonry
# ```{table} Density of different types of masonry.
# :name: masonry-densities
# | Material              | ρ [$kg/m^3$] |
# |---------------------------|------------------|
# | Clinker Brick             | 2000             |
# | Ordinary Façadestones      |                  |
# | - full (0% perforation)   | 1700             |
# | - perforated (20%)        | 1400             |
# | - hollow (35%)            | 1100             |
# | Facing Brick (20%)        | 1800             |
# | Sand-lime Bricks          | 1850             |
# ```
#
# ### Concrete masonry units
# ```{table} Concrete masonry densities.
# :name: concrete-masonry-densities
# | Material              | ρ [$kg/m^3$] |
# |---------------------------|------------------|
# | - light                    | 800-1500         |
# | - medium                   | 1500-1900        |
# | - heavy                    | 1900-2300        |
# | Cellular Concrete          | 500-800          |
# | Gypsum Blocks              | 1100             |
# | Tiles                      |                  |
# | - porous                   | 1900             |
# | - non porous               | 2300             |
# ```
#
# ### Concrete
# ```{table} Concrete densities.
# :name: concrete-densities
# | Material              | ρ [$kg/m^3$] |
# |---------------------------|------------------|
# | Lightweight Concrete      | <2000            |
# | Normal Concrete           | 2300-2450        |
# | Heavy Concrete            | <2800            |
# | Reinforced Concrete       | 2400-2550        |
# | Structural Lightweight Concrete | 1200-2000 |
# | Foamed Concrete           | 300-1400         |
# ```
#
# ```{note}
# The values above are given in [$kg/m^3$], which is not the same as [$kN/m^3$]!
# ```

# %% [markdown]
# ## Materials (all)
# ```{table} All materials and densities.
# :name: all-material-densities.
# | Material                        | ρ [kg/m³] | Material                     | ρ [kg/m³] |
# |----------------------------------|-----------|------------------------------|-----------|
# | Aluminium, cast                  | 2768      | Lead, cast                   | 11328     |
# | Artificial stone                 | 2304      | Lead, sheet                  | 11358     |
# | Ashes, coal                      | 719       | Marble                       | 2642      |
# | Asphalt, paving                  | 2308      | Plaster                      | 1538      |
# | Ballast, brick, gravel           | 1788      | Plaster, in barrels          | 848       |
# | Barley, in bags                  | 576       | Potash                       | 3276      |
# | Barley, in bulk                  | 640       | Reinforced concrete 2%        | 2401      |
# | Bleach, in barrels               | 512       | Reinforced concrete 3%        | 2503      |
# | Blockwork                        | 1305-2202 | Rosin, in barrels            | 769       |
# | Brass, cast                      | 8431      | Rubber                       | 960       |
# | Brass, rolled                    | 8546      | Saltpetre                    | 1072      |
# | Brickwork                        | 1549-2365 | Sand, dry                    | 1598      |
# | Bronze                           | 8386      | Sand, wet                    | 1998      |
# | Cement, in bags                  | 1345      | Screws, nails, in packages   | 1600      |
# | Cement, in barrels               | 1168      | Slate                        | 2877      |
# | Cement, mortar                   | 1678      | Soda ash, in barrels         | 992       |
# | Cement, Portland loose           | 1438      | Soda, caustic, in drums      | 1409      |
# | Clay, china, kaolin              | 2209      | Steel, cast                  | 8002      |
# | Clay, damp, plastic              | 1788      | Steel, rolled                | 8002      |
# | Clay, potters, dry               | 1920      | Straw, in bales, compress    | 304       |
# | Coal, loose                      | 896       | Sulphuric acid               | 960       |
# | Coke, loose                      | 480       | Tar                          | 1024      |
# | Concrete, breeze                 | 1538      | Terracotta                   | 1794      |
# | Concrete, brick                  | 1918      | Timber, pine, spruce         | 481       |
# | Concrete, stone                  | 2308      | Timber, pitch pine           | 673       |
# | Copper, cast                     | 8801      | Timber, redwood              | 561       |
# | Copper, rolled                   | 8930      | Timber, teak, oak            | 721       |
# | Crockery, in crates              | 640       | Tin, cast                    | 7282      |
# | Earth, dry, loose                | 1152      | Tin, rolled                  | 7392      |
# | Earth, dry, rammed               | 1788      | Water, fresh                 | 1000      |
# | Earth, moist, packed             | 1538      | Water, sea                   | 1024      |
# | Flint                            | 2640      | Wheat, in bags               | 624       |
# | Flour, in bags                   | 721       | Wheat, in bulk               | 721       |
# | Freestone, dressed               | 2398      | White lead, dry              | 138       |
# | Freestone, rubble                | 2238      | White lead, paste            | 2785      |
# | Glycerine, in cases              | 832       | Wire, in coils               | 1185      |
# | Glass, in crates                 | 960       | Zinc                         | 6993      |
# | Glass, plate                     | 2787      |                              |           |
# | Glass, sheet                     | 2497      |                              |           |
# | Granite, dressed                 | 2642      |                              |           |
# | Granite, rubble                  | 2477      |                              |           |
# | Gravel                           | 1918      |                              |           |
# ```
#
# ```{note}
# The values above are given in [$kg/m^3$], which is not the same as [$kN/m^3$]!
# ```

# %% [markdown]
# ## Action per unit surface area for composed structures
#
# ```{table} Force per unit surface for composed structures.
# :name: force-per-unit-for-composed-structures
# | Material                              | [$kN/m^2$] | Material                                         | [$kN/m^2$] |
# |--------------------------------------|---------|-------------------------------------------------|---------|
# | Steel façade elements                | 0.05-0.13 | Polymer foils                                 | 0.02    |
# | Façade insulation                    | 0.015-0.05 | Corrugated sheet <br> fibre reinforced cement   |         |
# | Timber floor + beams                 | 0.3     | Plate only                                     | 0.15    |
# | Steel roof sheeting                  | 0.05-0.18 | Plate + connections and purlins               | 0.25    |
# | - e.g. Steel roof sheet (t=0.75 mm) | 0.11    | corrugated sheet - polymers                   | 0.02    |
# | Insulation and roofing               | 0.10-0.20 | Corrugated steet - galvanized                 |         |
# | Bitumenlayers + connectons and purlins | 0.15  |                                                 |         |
# | Glass fabric 2 layers               | 0.07    | Roof tiles + underlay and purlins             | 0.65    |
# | Glass fabric 3 layers               | 0.1     | Flat roof + beams and underlay <br> (no gravel)    | 0.36    |
# | Shingles                             | 0.07    |                                                 |         |
# ```
