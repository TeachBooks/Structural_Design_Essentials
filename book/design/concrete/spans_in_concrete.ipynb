# %% [markdown]
# ## Spans in concrete
# ```{figure} Images/Spans_Concrete.jpg
# ---
# scale: 100%
# ---
# Spans in concrete - overview of structural typologies sorted on span
# ```
#
# ## Rules of thumb
# The 'rules of thumb' (Dutch: 'vuistregels') are to be seen as a quick way to estimate dimensions of structural members, mostly based on span. These *estimated* dimensions serve as input only for a early design stage calculation (e.g. check of capacity or deformation), after which you will use more advanced design rules (e.g. Eurocode) for a more accurate calculation. Mind that you should *not* use them the other way around, as if the rules of thumb were some law that should be respected.
#
# ```{figure} Images/Main_Floorbeams1.jpg
# ---
# scale: 50%
# ---
# Rectangular beams in cast on-site, traditionally reinforced concrete (= no prestress)
# ```
# Single span (beam on two support points)
# $L = 2$ to $20$ m
# $h = 200$ to $2000$ mm
# $h = L/8$ to $L/12$
# $b = h/3$ to $h/2$
#
# Multiple spans (continuous beam on 3 or more support points)
# $h = L/10$ to $L/15$
# $b = h/3$ to $h/2$
#
# -------------------------------------------------------
# ```{figure} Images/Prestressed_Floorbeams.jpg
# ---
# scale: 50%
# ---
# Rectangular beams in cast on-site, prestressed concrete
# ```
# Single span (beam on two support points)
# $L$: same
# $h$: same
# $h = L/15$ to $L/20$
# $b = h/4$ to $h/3$
#
# Multiple spans (continuous beam on 3 or more support points)
# $h = L/17$ to $L/22$
# $b = h/4$ to $h/3$
#
# -------------------------------------------------------
