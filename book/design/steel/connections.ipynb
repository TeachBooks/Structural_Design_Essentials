# %% [markdown]
# # Connections

# %% [markdown]
# ## Cont. column-beam
#
# ```{figure} Images/Column_Beam1.jpg
#
# Connection with bolted angles
# ```
#
# ```{figure} Images/Column_Beam1.1.jpg
#
# Beam-column connection with endplate. The endplate is welded to the beam in the workshop and bolted to the column on site.
# ```
#
# ```{figure} Images/Column_Beam2.jpg
#
# Connection with welded enplate, bolted to column
# ```
#
# ```{figure} Images/Column_Beam2.1.jpg
#
# Beam-column connection with bolted endplates. The beams are also connected to the web of the column.
# ```
#
# ```{figure} Images/Column_Beam3.jpg
#
# Connection with elongated endplate, bolted to stiffened column
# ```
#
# ```{figure} Images/Column_Beam3.1.jpg
#
# A stiffened beam-column connection. This way a rigid steel frame is obtained. A plastic calculation is possible for these structures.
# ```
#
# ## Beam-beam
#
# ```{figure} Images/Beam_Beam1.jpg
#
# Connection with bolted angles
# ```
#
# ```{figure} Images/Beam_Beam1.1.jpg
#
# Connection with bolted angles
# ```
#
# ```{figure} Images/Beam_Beam2.jpg
#
# Connection with welded endplate, bolted to other element
# ```
#
# ```{figure} Images/Beam_Beam2.1.jpg
#
# Connection with welded endplate, bolted to other element
# ```
#
# ```{figure} Images/Beam_Beam3.jpg
#
# Connection with elongated endplate, bolted to other (stiffened) element.
# ```
#
# ```{figure} Images/Beam_Beam3.1.jpg
#
# Connection with elongated endplate, bolted to other (stiffened) element.
# ```
#
# ## Beam-wall
#
# ```{figure} Images/Beam_Wall1.jpg
#
# Support on elastomer, with lock bolt.
# ```
#
# ```{figure} Images/Beam_Wall2.jpg
#
# Support on elastomer, with lock bolt.
# ```
#
# ```{figure} Images/Beam_Wall3.jpg
#
# Support with steel axle.
# ```
#
# ## Center-column-beam
#
# ```{figure} Images/Center_Column_Beam1.jpg
#
# Welded endplate with four bolts.
# ```
#
# ```{figure} Images/Center_Column_Beam2.jpg
#
# Welded endplate with four bolts with welded stiffeners on beam web.
# ```
#
# ```{figure} Images/Center_Column_Beam3.jpg
#
# Elongated welded endplate with eight bolts, welded stiffeners on beam web.
# ```
#
# ```{figure} Images/Center_Column_Beam4.jpg
#
# Welded endplate with four bolts.
# ```
#
# ```{figure} Images/Center_Column_Beam5.jpg
#
# Welded endplate with welded stiffeners on beam web.
# ```
#
# ```{figure} Images/Center_Column_Beam6.jpg
#
# Welded endplate with welded stiffeners on beam web.
# ```
#
# ```{figure} Images/Center_Column_Beam7.jpg
#
# Simple connection with welded endplate. During erection the beam is bolted into place (car park near Delft public library).
# ```
#
# ```{figure} Images/Center_Column_Beam8.jpg
#
# Welded endplate with four bolts, placed outside the column section.
# ```
#
# ## Column-support
#
# ```{figure} Images/Column_Support1.jpg
#
# Column support with welded endplate and a single row of bolts.
# ```
#
# ```{figure} Images/Column_Support1.1.jpg
#
# Column support with welded endplate and a single row of bolts.
# ```
#
# ```{figure} Images/Column_Support2.jpg
#
# Column support with welded endplate and four bolts.
# ```
# ```{figure} Images/Column_Support2.1.jpg
#
# Column support with welded endplate and four bolts.
# ```
#
# ```{figure} Images/Column_Support3.jpg
#
# Column support with bolts outside column section for extra stiffness.
# ```
# ```{figure} Images/Column_Support3.1.jpg
#
# Column support with bolts outside column section for extra stiffness.
# ```
#
# ## End column-beam
#
# ```{figure} Images/End_Column_Beam1.jpg
#
# Welded endplate with two bolts.
# ```
#
# ```{figure} Images/End_Column_Beam2.jpg
#
# Connection with bolted angles.
# ```
#
# ```{figure} Images/End_Column_Beam3.jpg
#
# Welded elongated endplate with top plate and stiffeners for extra stiffness.
# ```
#
# ```{figure} Images/End_Column_Beam4.jpg
#
# Welded endplate with two bolts.
# ```
#
# ```{figure} Images/End_Column_Beam5.jpg
#
# Welded endplate with six bolts.
# ```
#
# ```{figure} Images/End_Column_Beam6.jpg
#
# Welded endplate with extra plate in tension zone and stiffeners.
# ```
#
# ```{figure} Images/End_Column_Beam7.jpg
#
# Welded endplate with four bolts.
# ```
#
# ```{figure} Images/End_Column_Beam8.jpg
#
# Welded elongated endplate with four bolts and stiffeners.
# ```
#
# ```{figure} Images/End_Column_Beam9.jpg
#
# Connection between castellated beam and column. Be aware of the reduced shear capacity of castellated beams.
# ```
#
# ```{figure} Images/End_Column_Beam10.jpg
#
# Beam-column connection using bolted angles.
# ```
