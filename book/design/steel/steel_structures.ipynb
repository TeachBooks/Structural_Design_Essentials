# %% [markdown]
# ## Steel columns
# ```{figure} Images/Steel_Columns1.jpg
# ---
# ---
# Rolled and welded H- and U-sections
# ```
# single storey:
# $h_{st} = 2$ to $8$ m
# $d = h_{st}/20$ to $h_{st}/25$
#
# multi storey:
# $h_{st} = 2$ to $4$ m
# $d = h_{st}/7$ to $h_{st}/18$
#
# -------------------------------------------------------
# ```{figure} Images/Steel_Columns2.jpg
# ---
# ---
# Hollow sections
# ```
# single storey:
# $h_{st} = 2$ to $8$ m
# $d = h_{st}/20$ to $h_{st}/35$
#
# multi storey:
# $h_{st} = 2$ to $4$ m
# $d = h_{st}/7$ to $h_{st}/28$
#
# -------------------------------------------------------
# ```{figure} Images/Steel_Columns3.jpg
# ---
# ---
# Casted-in and concrete-filled columns always contain extra reinforcement
# ```
# $h_{st} = 2$ to $4$ m
# $d = h_{st}/6$ to $h_{st}/15$
#
# -------------------------------------------------------
# ## Main floorbeams
# ```{figure} Images/Main_Floorbeams1.jpg
# ---
# ---
# Wide flange (H) sections and hollow sections.
# ```
# $l = 4$ to $12$ m
# $h = 100$ to $500$ mm
# $h = l/18$ to $l/28$
#
# -------------------------------------------------------
# ```{figure} Images/Main_Floorbeams2.jpg
# ---
# ---
# I- and U-sections as main beams.
# ```
# $l = 6$ to $30$ m
# $h = 200$ to $500$ mm
# $h = l/15$ to $l/20$
#
# -------------------------------------------------------
# ```{figure} Images/Main_Floorbeams3.jpg
# ---
# ---
# Truss beam.
# ```
# $l = 12$ to $45$ m
# $h = 1000$ to $4000$ mm
# $h = l/8$ to $l/15$
#
# -------------------------------------------------------
# ```{figure} Images/Main_Floorbeams4.jpg
# ---
# ---
# Top hat beams with added compression layer, with or without shear connections.
# ```
# $l = 7$ to $15$ m
# $h = 300$ to $1000$ mm
# $h = l/20$ to $l/25$
#
# -------------------------------------------------------
# ## Floors
# ```{figure} Images/Composite_Floors.jpg
# ---
# ---
# Composite floor with extra reinforcement.
# ```
# $l = 2$ to $4$ m
# $h = 100$ to $150$ mm
# $h = l/25$ to $l/30
#
# -------------------------------------------------------
# ## Main roofbeams
# ```{figure} Images/Roofbeams1.jpg
# ---
# ---
# Wide flange (H) sections and hollow sections.
# ```
# $l = 6$ to $14$ m
# $h = 100$ to $500$ mm
# $h = l/20$ to $l/30$
#
# -------------------------------------------------------
# ```{figure} Images/Roofbeams2.jpg
# ---
# ---
# Truss made of cold formed sections.
# ```
# $l = 12$ to $75$ m
# $h = l/10$ to $l/18$
#
# -------------------------------------------------------
# ```{figure} Images/Roofbeams3.jpg
# ---
# ---
# Truss made of formed sections.
# ```
# $l = 5$ to $28$ m
# $h = 300$ to $1000$ mm
# $h = l/15$ to $l/25$
#
# -------------------------------------------------------
# ```{figure} Images/Roofbeams4.jpg
# ---
# ---
# Truss made of hot rolled sections
# ```
# $l = 8$ to $20$ m
# $h = 300$ to $1000$ mm
# $h = l/5$ to $l/10$
#
# -------------------------------------------------------
# ```{figure} Images/Roofbeams5.jpg
# ---
# ---
# Space frame made of hot rolled sections.
# ```
# $l = 30$ to $150$ m
# $h = l/15$ to $l/30$
#
# -------------------------------------------------------
# ## Purlins roofstructures
# ```{figure} Images/Purlins1.jpg
# ---
# ---
# Steel purlin roofstructure.
# ```
# $l = 3$ to $12$ m
# $h = 120$ to $300$ mm
# $h = l/25$ to $l/35$
#
# -------------------------------------------------------
# ```{figure} Images/Purlins2.jpg
# ---
# ---
# Steel purlins roofstructure.
# ```
# $l = 6$ to $40$ m
# $h = 200$ to $1000$ mm
# $h = l/18 - l/26$
#
# -------------------------------------------------------
#
# ## Roofing plates
# ```{figure} Images/Roofing_Plate1.jpg
# ---
# ---
# Cold formed corrugated steel roofing plate.
# ```
# $l = 2$ to $6$ m
# $h = 25$ to $120$ mm
# $h = l/40$ to $l/70$
#
# -------------------------------------------------------
# ```{figure} Images/Roofing_Plate2.jpg
# ---
# ---
# Cold formed corrugated steel sandwich panel with foam core.
# ```
# $l = 2$ to $3$ m
# $h = 75$ to $150$ mm
# $h = l/25$ to $l/30$
